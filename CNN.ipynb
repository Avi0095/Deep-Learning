# %% [markdown]
# import the library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# preprocessing the training set

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Train data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

training_set = train_datagen.flow_from_directory(
    '/content/cats_dogs_light/train',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

# Test data
test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory(
    '/content/cats_dogs_light/test',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 1000 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %% [markdown]
# initializing the CNN

# %%
cnn=tf.keras.models.Sequential()

# %% [markdown]
# step-1:Convolution layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))

# %% [markdown]
# step-2:pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# Adding a second layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Full connection

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %% [markdown]
# Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# Compiling the CNN

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Train the CNN on training set and test it

# %%
cnn = Sequential()

# Match training_set image size
cnn.add(Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Conv2D(64, (3,3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))

cnn.add(Flatten())  # output = 36*36*64 = 82944
cnn.add(Dense(128, activation='relu'))
cnn.add(Dense(1, activation='sigmoid'))

cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5414 - loss: 1.1747
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.5411 - loss: 1.1648 - val_accuracy: 0.6050 - val_loss: 0.6809
# Epoch 2/25
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.5642 - loss: 0.6691 - val_accuracy: 0.5975 - val_loss: 0.6426
# Epoch 3/25
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.6335 - loss: 0.6312 - val_accuracy: 0.6025 - val_loss: 0.6510
# Epoch 4/25
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.6740 - loss: 0.6131 - val_accuracy: 0.6600 - val_loss: 0.6325
# Epoch 5/25
# ...
